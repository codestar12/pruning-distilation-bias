# %%
from src.analytics import df_builder
import pickle

# %%
with open('dfs.pickle', 'rb') as f:
    dfs = pickle.load(f)

# %%
dfs.PIEs
# Out:
#       PIEs                        method  sparsity    block1    block2  \
# 0    674.0                Struct Pruning      30.0  0.110764  0.230935
# 1    711.0                Struct Pruning      45.0  0.125646  0.266176
# 2    741.0                Struct Pruning      60.0  0.168584  0.319266
# 3    887.0                Struct Pruning      75.0  0.226446  0.391265
# 4   1407.0                Struct Pruning      90.0  0.232032  0.426173
# 5    353.0  Similarity Preserving Struct      30.0  0.074923  0.162626
# 6    654.0  Similarity Preserving Struct      45.0  0.114779  0.239872
# 7    737.0  Similarity Preserving Struct      60.0  0.160767  0.305387
# 8    860.0  Similarity Preserving Struct      75.0  0.220938  0.385699
# 9   1380.0  Similarity Preserving Struct      90.0  0.226879  0.418396
# 10   543.0                     KD Struct      30.0  0.079326  0.178671
# 11   675.0                     KD Struct      45.0  0.108775  0.230964
# ...
